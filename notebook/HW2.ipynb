# %% [markdown]
# ### **Problem 1**
# Generate an expression tree (Binary tree) from a postfix expression
#
# ### **Explaination**

# %%
#Imports

import csv

# %%
def csv_to_list(filename):
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        data_list = list(reader)
    return data_list

# %%
def generate_tree(filename) -> dict:
    operators = ['+', '-', '*', '/', '(', ')']
    stack = []
    input_list = csv_to_list(filename)
    for item in input_list:
        node=item.strip()
        if node not in operators:
            stack.append(node)
        else:
            if len(stack)<2:
                raise ValueError('Invalid expression:not enough operands')
            stack.pop()
            stack.pop()
    if len(stack)!=1:
        raise ValueError('Invalid expression: missing operands')
    return stack[0]

# %%
filename = 'data\p1_construct_tree.csv'
root = generate_tree(filename)
print(root)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27408\1965741322.py in <module>
#       1 filename = '../data/p1_construct_tree.csv'
# ----> 2 root = generate_tree(filename)
#       3 print(root)
#
# ~\AppData\Local\Temp\ipykernel_27408\4194623865.py in generate_tree(filename)
#       2     operators = ['+', '-', '*', '/', '(', ')']
#       3     stack = []
# ----> 4     input_list = csv_to_list(filename)
#       5     for item in input_list:
#       6         node=item.strip()
#
# ~\AppData\Local\Temp\ipykernel_27408\3901644375.py in csv_to_list(filename)
#       1 def csv_to_list(filename):
# ----> 2     with open(filename, 'r') as file:
#       3         reader = csv.reader(file)
#       4         data_list = list(reader)
#       5     return data_list
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/p1_construct_tree.csv'
