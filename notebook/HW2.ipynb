# %% [markdown]
# ### **Problem 1**
# Generate an expression tree (Binary tree) from a postfix expression
#
# ### **Explaination**
# Stack is the appropriate ADT for these operations hence i have used Stack whic allows pop an dpush oprations.

# %%
def csv_to_list(filename):
    with open(filename, 'r') as file:
        data_list = []
        for line in file:
           line = line.strip().replace('"', '').split(",")
           data_list.append(line)
    return data_list

# %%
def construct_tree(filename) -> dict:
    operators = ['+', '-', '*', '/', '(', ')']
    root_node = {}
    input_list = csv_to_list(filename)
    for i, input in enumerate(input_list):
        stack = []
        for node in input:
            if node not in operators:
                stack.append(node)
            else:
                if len(stack)<2:
                    raise ValueError('Invalid expression:not enough operands')
                right = stack.pop()
                left = stack.pop()
                stack.append({"value": node, "left": left, "right": right})
        root_node[str(i)] = stack[0]
        if len(stack)!=1:
            raise ValueError('Invalid expression: missing operands')
    
    return root_node

# %%
filename = '..\data\p1_construct_tree.csv'
input_list = csv_to_list(filename)
print(input_list)
# Out:
# [['3', '4', '+'], ['3', '4', '+', '2', '*'], ['5', '6', '7', '*', '+'], ['8', '3', '2', '+', '*'], ['9', '5', '1', '-', '*'], ['7', '2', '3', '*', '+'], ['10', '4', '2', '*', '+'], ['6', '3', '/', '2', '+'], ['12', '3', '4', '+', '*'], ['15', '5', '/', '2', '*'], ['20', '4', '/', '3', '+'], ['9', '3', '/', '2', '*'], ['14', '7', '/', '5', '+'], ['11', '2', '3', '*', '-'], ['18', '3', '/', '6', '+'], ['7', '4', '2', '*', '+'], ['13', '5', '2', '*', '+'], ['16', '4', '/', '2', '*'], ['21', '7', '/', '3', '+'], ['25', '5', '/', '4', '*'], ['30', '6', '/', '2', '*']]

# %%
filename = '..\data\p1_construct_tree.csv'
root = construct_tree(filename)
for key, value in root.items():
    print(f'Root node for expression : {int(key)+1}: {value}')
# Out:
# Root node for expression : 1: {'value': '+', 'left': '3', 'right': '4'}
# Root node for expression : 2: {'value': '*', 'left': {'value': '+', 'left': '3', 'right': '4'}, 'right': '2'}
# Root node for expression : 3: {'value': '+', 'left': '5', 'right': {'value': '*', 'left': '6', 'right': '7'}}
# Root node for expression : 4: {'value': '*', 'left': '8', 'right': {'value': '+', 'left': '3', 'right': '2'}}
# Root node for expression : 5: {'value': '*', 'left': '9', 'right': {'value': '-', 'left': '5', 'right': '1'}}
# Root node for expression : 6: {'value': '+', 'left': '7', 'right': {'value': '*', 'left': '2', 'right': '3'}}
# Root node for expression : 7: {'value': '+', 'left': '10', 'right': {'value': '*', 'left': '4', 'right': '2'}}
# Root node for expression : 8: {'value': '+', 'left': {'value': '/', 'left': '6', 'right': '3'}, 'right': '2'}
# Root node for expression : 9: {'value': '*', 'left': '12', 'right': {'value': '+', 'left': '3', 'right': '4'}}
# ...

# %% [markdown]
# ### **Problem 2**

# %% [markdown]
# - Implement functions to print prefix, infix, postfix expressions using traversal methods. Use pre-order traversal (root, left, right) to generate prefix notation. Use in-order traversal (left, root, right) for infix notation with appropriate parentheses. Use post-order traversal (left, right, root) to generate postfix notation.
# - Requirements:
#       ➢ Return the expression as a list of elements
#       ➢ For infix: Add parentheses to maintain correct operator precedence (even for the outermost expressions. Also, treat parentheses as individual elements in the returned list)
#       ➢ Handle empty trees gracefully
# - Example (using the tree from Problem 1):
#
#     Prefix: *, +, 3, 4, 2 Infix: (, (, 3, +, 4, ), *, 2, ) Postfix: 3, 4, +, 2, *

# %% [markdown]
# ### **Explianation**
#
# 1. Each row in csv file contain sone airthamatic expression, with multiple traversal formats.
# 2. Build an expression tree from postfix (generate_tree) from problem 1
# 3. Traverse the tree to output expressions
# 4. Compare with the expected outputs in the CSV

# %%
def _split_csv_with_quotes(line):

    fields = []
    cur = []
    in_quotes = False
    i = 0
    while i < len(line):
        ch = line[i]
        if ch == '"':
            in_quotes = not in_quotes
        elif ch == ',' and not in_quotes:
            fields.append("".join(cur).strip())
            cur = []
        else:
            cur.append(ch)
        i += 1
    fields.append("".join(cur).strip())

    # Remove surrounding quotes if any
    cleaned = []
    for f in fields:
        f = f.strip()
        if len(f) >= 2 and f[0] == '"' and f[-1] == '"':
            f = f[1:-1]
        cleaned.append(f)
    return cleaned

# %%
def read_rows(filename):
    """
    Reads p2_traversals.csv and returns a list of rows:
      each row is (postfix_list, expected_prefix_list, expected_infix_list, expected_postfix_list)
    """
    rows = []
    with open(filename, "r") as f:
        for raw in f:
            line = raw.strip()
            if not line:
                continue
            cols = _split_csv_with_quotes(line)
            # In case of any stray parsing issues, skip bad lines
            if len(cols) < 4:
                continue

            postfix = cols[0].split(",") if cols[0] else []
            exp_prefix = cols[1].split(",") if cols[1] else []
            exp_infix = cols[2].split(",") if cols[2] else []
            exp_postfix = cols[3].split(",") if cols[3] else []
            rows.append((postfix, exp_prefix, exp_infix, exp_postfix))
    return rows

# %%
def construct_tree_2(tokens):
    """
    Builds a proper binary expression tree from postfix token list.
    Node format: {"value": token, "left": <node>, "right": <node>}
    Leaf nodes have left/right = None.
    """
    ops = {"+", "-", "*", "/"}
    stack = []
    for t in tokens:
        if t not in ops:
            stack.append({"value": t, "left": None, "right": None})
        else:
            if len(stack) < 2:
                raise ValueError("Invalid postfix expression: not enough operands")
            right = stack.pop()
            left = stack.pop()
            stack.append({"value": t, "left": left, "right": right})
    if len(stack) != 1:
        raise ValueError("Invalid postfix expression: missing operators/operands")
    return stack[0]

# %%
def prefix_expression(root):
    if root is None:
        return []
    out = [str(root["value"])]
    out += prefix_expression(root["left"])
    out += prefix_expression(root["right"])
    return out

def postfix_expression(root):
    if root is None:
        return []
    out = []
    out += postfix_expression(root["left"])
    out += postfix_expression(root["right"])
    out.append(str(root["value"]))
    return out

def infix_expression(root):
    """
    In-order traversal with parentheses as separate list items.
    Parenthesizes every internal node (matches the provided expected format).
    """
    if root is None:
        return []
    l = root["left"]
    r = root["right"]
    v = str(root["value"])

    # leaf
    if l is None and r is None:
        return [v]

    # internal
    return ["("] + infix_expression(l) + [v] + infix_expression(r) + [")"]

# %%
filename_2 = "../data/p2_traversals.csv"
rows = read_rows(filename_2)
results = []
all_ok = True
for idx, (postfix_in, exp_pre, exp_in, exp_post) in enumerate(rows):
    tree = construct_tree_2(postfix_in)

    got_pre = prefix_expression(tree)
    got_in = infix_expression(tree)
    got_post = postfix_expression(tree)

    ok = (got_pre == exp_pre) and (got_in == exp_in) and (got_post == exp_post)
    if not ok:
        all_ok = False

    results.append({
        "row": idx + 1,
        "input_postfix": postfix_in,
        "prefix": got_pre,
        "infix": got_in,
        "postfix": got_post,
        "matches_expected": ok
    })

print("Total rows:", len(results))
print("All match expected:", all_ok)
# Out:
# Total rows: 22
# All match expected: True

# %%
for r in results:
    print(f"Row {r['row']}: matches expected? {r['matches_expected']}")
    print(f"  Input Postfix: {r['input_postfix']}")
    print(f"  Got Prefix: {r['prefix']}")
    print(f"  Got Infix: {r['infix']}")
    print(f"  Got Postfix: {r['postfix']}")
# Out:
# Row 1: matches expected? True
#   Input Postfix: ['3', '4', '+']
#   Got Prefix: ['+', '3', '4']
#   Got Infix: ['(', '3', '+', '4', ')']
#   Got Postfix: ['3', '4', '+']
# Row 2: matches expected? True
#   Input Postfix: ['3', '4', '+', '2', '*']
#   Got Prefix: ['*', '+', '3', '4', '2']
#   Got Infix: ['(', '(', '3', '+', '4', ')', '*', '2', ')']
#   Got Postfix: ['3', '4', '+', '2', '*']
# Row 3: matches expected? True
#   Input Postfix: ['5', '6', '7', '*', '+']
#   Got Prefix: ['+', '5', '*', '6', '7']
#   Got Infix: ['(', '5', '+', '(', '6', '*', '7', ')', ')']
#   Got Postfix: ['5', '6', '7', '*', '+']
# Row 4: matches expected? True
#   Input Postfix: ['8', '3', '2', '+', '*']
#   Got Prefix: ['*', '8', '+', '3', '2']
#   Got Infix: ['(', '8', '*', '(', '3', '+', '2', ')', ')']
#   Got Postfix: ['8', '3', '2', '+', '*']
# Row 5: matches expected? True
#   Input Postfix: ['9', '5', '1', '-', '*']
#   Got Prefix: ['*', '9', '-', '5', '1']
# ...

# %% [markdown]
# ### **Problem 3**
#   Evaluate a postfix expression using a stack. That is, implement a function that evaluates a postfix expression without constructing an expression tree.

# %% [markdown]
# ### Explaination
# 1. Postfix (RPN) rule says that operands come first, then the operator.
# 2. while scanning nodes from left to right ,it its number we will push it onto the stack
# 3. If node is operater we will pop the second operand followed by first operand
# 4. Then we will compute the airthmatic operation.
# 5. At the end the stack will contain the exactly only one value the final answer.
# 6. if '/' operator has '0' as right operand we will raise ZeroDivisionError.

# %%
def csv_to_list_and_ans(filename):
    with open(filename, 'r') as file:
        data_list = []
        ans=[]
        for line in file:
           line = line.strip().replace('"', '').split(",")
           ans.append(line[-1]) 
           line=line[0].split()  # remove extra spaces
           data_list.append(line)  # all columns except last one as input
            # assuming last column is expected result
    return data_list ,ans

filename_3="../data/p3_eval_postfix.csv"
input_list, ans = csv_to_list_and_ans(filename_3)
for i ,j in zip(input_list, ans):
    print(f"input: {i}, expected: {j}")
# Out:
# input: ['5', '1', '2', '+', '4', '*', '+', '3', '-'], expected: 14
# input: ['3', '4', '+', '2', '*'], expected: 14
# input: ['10', '2', '/'], expected: 5
# input: ['6', '3', '/', '2', '+'], expected: 4
# input: ['7', '2', '3', '*', '+'], expected: 13
# input: ['12', '3', '4', '+', '*'], expected: 84
# input: ['15', '5', '/', '2', '*'], expected: 6
# input: ['20', '4', '/', '3', '+'], expected: 8
# input: ['9', '3', '/', '2', '*'], expected: 6
# input: ['14', '7', '/', '5', '+'], expected: 7
# input: ['11', '2', '3', '*', '-'], expected: 5
# input: ['18', '3', '/', '6', '+'], expected: 12
# input: ['7', '4', '2', '*', '+'], expected: 15
# input: ['13', '5', '2', '*', '+'], expected: 23
# input: ['16', '4', '/', '2', '*'], expected: 8
# input: ['21', '7', '/', '3', '+'], expected: 6
# input: ['25', '5', '/', '4', '*'], expected: 20
# input: ['30', '6', '/', '2', '*'], expected: 10
# input: ['1', '2', '+', '3', '*'], expected: 9
# input: ['8', '4', '/', '2', '*'], expected: 4
# ...

# %%
def apply_op(node,right,left,stack):
    if node == "+":
        stack.append(left + right)
    elif node == "-":
        stack.append(left - right)
    elif node == "*":
        stack.append(left * right)
    else:
        try:
            stack.append(int(left / right))
        except ZeroDivisionError:   ##### Handing in case of division by zero
            stack.append("DIVZERO")  
    return stack

# %%
def evaluate_postfix(filename) -> dict:
    operators = ['+', '-', '*', '/', '(', ')']
    computed_answer = {}
    input_list, ans = csv_to_list_and_ans(filename)
    for i, (input, actual_ans) in enumerate(zip(input_list, ans)):
        stack = []
        for node in input:
            if node not in operators:
                stack.append(node)
            else:
                if len(stack)<2:
                    raise ValueError('Invalid expression:not enough operands')
                right = stack.pop()
                left = stack.pop()
                stack=apply_op(node,int(right),int(left),stack)
        if len(stack)!=1:
            raise ValueError('Invalid expression: missing operands')
        if actual_ans==str(stack[0]):
            computed_answer[str(i)] = f"test case {i+1} passed successfully with final value: {stack[0]}"
               
    
    return computed_answer

# %%
answers=evaluate_postfix(filename_3)
# Out:
# Processing node: 10, current stack: []
# Processing node: 2, current stack: ['10']
# Processing node: /, current stack: ['10', '2']
# After applying operator / on 10 and 2, stack is now: [5]

# %%
answers
# Out:
# {'0': 'test case 1 passed successfully with final value: 14',
#  '1': 'test case 2 passed successfully with final value: 14',
#  '2': 'test case 3 passed successfully with final value: 5',
#  '3': 'test case 4 passed successfully with final value: 4',
#  '4': 'test case 5 passed successfully with final value: 13',
#  '5': 'test case 6 passed successfully with final value: 84',
#  '6': 'test case 7 passed successfully with final value: 6',
#  '7': 'test case 8 passed successfully with final value: 8',
#  '8': 'test case 9 passed successfully with final value: 6',
#  '9': 'test case 10 passed successfully with final value: 7',
#  '10': 'test case 11 passed successfully with final value: 5',
#  '11': 'test case 12 passed successfully with final value: 12',
#  '12': 'test case 13 passed successfully with final value: 15',
#  '13': 'test case 14 passed successfully with final value: 23',
#  '14': 'test case 15 passed successfully with final value: 8',
# ...

# %%
def split_csv_line_with_quotes(line):
    fields, cur, in_quotes = [], [], False
    i = 0
    while i < len(line):
        ch = line[i]
        if ch == '"':
            in_quotes = not in_quotes
        elif ch == ',' and not in_quotes:
            fields.append("".join(cur).strip())
            cur = []
        else:
            cur.append(ch)
        i += 1
    fields.append("".join(cur).strip())

    out = []
    for f in fields:
        f = f.strip()
        if len(f) >= 2 and f[0] == '"' and f[-1] == '"':
            f = f[1:-1]
        out.append(f)
    return out

# %%
P3_FILE = "../data/p3_eval_postfix.csv"




# ---------------- Stack ADT (NO OOP) ----------------
def stack_create():
    return {"data": [], "top": -1}

def stack_is_empty(st):
    return st["top"] == -1

def stack_push(st, x):
    st["data"].append(x)
    st["top"] += 1

def stack_pop(st):
    if stack_is_empty(st):
        raise IndexError("pop from empty stack")
    x = st["data"][st["top"]]
    st["data"].pop()
    st["top"] -= 1
    return x


def to_number(token):
    token = token.strip()
    if token == "":
        raise ValueError("Empty token")
    # int if possible, float if has '.'
    if "." in token:
        return float(token)
    return int(token)


def evaluate_postfix(expr_str):
    """
    Accept postfix as SPACE-separated string.
    Supports +, -, *, /
    Returns numeric result.
    Raises ZeroDivisionError on division by zero.
    """
    st = stack_create()
    ops = {"+", "-", "*", "/"}

    tokens = expr_str.strip().split()
    for t in tokens:
        if t in ops:
            b = stack_pop(st)  # right operand
            a = stack_pop(st)  # left operand

            if t == "+":
                stack_push(st, a + b)
            elif t == "-":
                stack_push(st, a - b)
            elif t == "*":
                stack_push(st, a * b)
            else:  # "/"
                if b == 0:
                    raise ZeroDivisionError("division by zero")
                stack_push(st, a / b)
        else:
            stack_push(st, to_number(t))

    result = stack_pop(st)
    if not stack_is_empty(st):
        raise ValueError("Invalid postfix expression: extra operands remain")
    return result


def read_p3_tests(filename):
    """
    Reads p3_eval_postfix.csv.
    Assumes each row:
      col0 = postfix expression (space-separated)
      col1 = expected result OR expected error text (optional)
    Returns list of (expr, expected)
    """
    tests = []
    with open(filename, "r") as f:
        for raw in f:
            line = raw.strip()
            if not line:
                continue
            cols = split_csv_line_with_quotes(line)

            # skip header if present
            c0 = cols[0].strip().lower() if len(cols) > 0 else ""
            c1 = cols[1].strip().lower() if len(cols) > 1 else ""
            if ("postfix" in c0) and ("expected" in c1):
                continue

            expr = cols[0].strip()
            expected = cols[1].strip() if len(cols) > 1 else None
            tests.append((expr, expected))
    return tests


# ---------------- Run tests from CSV ----------------
print("\nRUNNING TEST CASES FOR PROBLEM 3")
testcases = read_p3_tests(P3_FILE)

for i, (expr, expected) in enumerate(testcases, 1):
    try:
        got = evaluate_postfix(expr)

        if expected is not None and expected != "":
            exp_low = expected.lower()

            # if expected indicates error, but we got a number -> fail
            if ("error" in exp_low) or ("zerodivision" in exp_low) or ("division by zero" in exp_low):
                raise AssertionError(f"P3-{i} expected an error but got {got}")

            # compare numeric
            exp_num = float(expected) if "." in expected else int(expected)
            if got != exp_num:
                # allow 14 vs 14.0
                if isinstance(exp_num, int) and isinstance(got, float) and got == float(exp_num):
                    pass
                else:
                    raise AssertionError(f"P3-{i} failed: expected {exp_num}, got {got}")

        print(f"P3 Test {i} passed")

    except ZeroDivisionError:
        if expected is not None and expected.strip() != "":
            exp_low = expected.strip().lower()
            if ("zerodivision" in exp_low) or ("division by zero" in exp_low) or ("error" in exp_low):
                print(f"P3 Test {i} passed (caught ZeroDivisionError)")
            else:
                raise
        else:
            print(f"P3 Test {i}: ZeroDivisionError")

    except AssertionError as e:
        print(str(e))
        break

    except Exception as e:
        print(f"P3-{i} failed with {type(e).__name__}: {e}")
        break
# Out:
# RUNNING TEST CASES FOR PROBLEM 3
# P3 Test 1 passed
# P3 Test 2 passed
# P3 Test 3 passed
# P3 Test 4 passed
# P3 Test 5 passed
# P3 Test 6 passed
# P3 Test 7 passed
# P3 Test 8 passed
# P3 Test 9 passed
# P3 Test 10 passed
# P3 Test 11 passed
# P3 Test 12 passed
# P3 Test 13 passed
# P3 Test 14 passed
# P3 Test 15 passed
# P3 Test 16 passed
# P3 Test 17 passed
# P3 Test 18 passed
# P3 Test 19 passed
# P3 Test 20 passed
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15376\341198857.py in <module>
#     103 for i, (expr, expected) in enumerate(testcases, 1):
#     104     try:
# --> 105         got = evaluate_postfix(expr)
#     106
#     107         if expected is not None and expected != "":
#
# ~\AppData\Local\Temp\ipykernel_15376\341198857.py in evaluate_postfix(expr_str)
#      58             else:  # "/"
# ...
